# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/comp/zmzhang/tell-seq-pipeline/tellread/A1_tellread_done/longranger_final.tsv.insert_size")
plt.hist(df.loc[df["Insert_Size"] <= 1100]["Insert_Size"], bins=550, alpha=0.7, density=1)
plt.xlabel("Insert size")
plt.ylabel("Density")
# Out:
# Text(0, 0.5, 'Density')
